# %%
import altair as alt
import numpy as np
import pandas as pd
import torch

from collections import defaultdict
from pathlib import Path
from re import split
from tqdm import tqdm

# %% [markdown]
# # [1] **Line Count Heatmap**

# %%
line_stats = defaultdict(list)
for file in tqdm(Path('../../experiments/08_blase3D_HPC_test/emulator_states').glob('*0.0.pt'), total=657):
    state_dict = torch.load(file, 'cuda')
    tokens = split('[TGZ]', file.stem)
    line_stats['teff'].append(int(tokens[1]))
    line_stats['logg'].append(float(tokens[2]))
    line_stats['Z'].append(float(tokens[3]))
    line_stats['center'].append(state_dict['pre_line_centers'].cpu().numpy())
    line_stats['shift_center'].append(state_dict['lam_centers'].cpu().numpy())
    line_stats['amp'].append(state_dict['amplitudes'].cpu().numpy())
    line_stats['sigma'].append(state_dict['sigma_widths'].cpu().numpy())
    line_stats['gamma'].append(state_dict['gamma_widths'].cpu().numpy())
df = pd.DataFrame(line_stats).explode(['center', 'amp', 'sigma', 'gamma', 'shift_center'])
df['jitter'] = df.shift_center - df.center
# Out:
# 100%|██████████| 657/657 [00:01<00:00, 392.37it/s]

# %%
alt.Chart(df.groupby(['teff', 'logg']).size().reset_index(name='n_lines')).mark_rect()\
    .encode(x=alt.X('teff:O', title='Effective Temperature [K]'), y=alt.Y('logg:O', title='Surface Gravity'), color=alt.Color('n_lines:Q', title='Line Count', scale=alt.Scale(type='log')))\
    .properties(width=1000, height=400)\
    .configure_axis(labelFontSize=15, titleFontSize=24)\
    .configure_legend(labelFontSize=15, titleFontSize=15)
# Out:
# alt.Chart(...)

# %% [markdown]
# # [2] **PHOENIX Subset Discrete Manifold**

# %%
first_line = df.value_counts('center').index[1]
(alt.Chart(df.query('center == @first_line')).mark_rect()\
    .encode(x=alt.X('teff:O', title='Effective Temperature [K]'), y=alt.Y('logg:O', title='Surface Gravity'), color=alt.Color(f'amp:Q', title='Log-Amplitude'))\
    .properties(width=1000, height=400, title=f'Spectral Line at {first_line} Å') &\
alt.Chart(df.query('center == @first_line')).mark_rect()\
    .encode(x=alt.X('teff:O', title='Effective Temperature [K]'), y=alt.Y('logg:O', title='Surface Gravity'), color=alt.Color(f'sigma:Q', title='Gaussian Width'))\
    .properties(width=1000, height=400, title=f'Spectral Line at {first_line} Å'))\
    .configure_axis(labelFontSize=15, titleFontSize=24)\
    .configure_legend(labelFontSize=15, titleFontSize=15)\
    .configure_title(fontSize=25).resolve_scale(color='independent')
# Out:
# alt.VConcatChart(...)

# %%
for row in df.sort_values(['teff', 'logg', 'Z']).query('center == 11617.66').iterrows():
    print(row)
# Out:
# (107, teff                    2300
# logg                     2.0
# Z                        0.0
# center              11617.66
# shift_center    11617.650814
# amp                -2.179514
# sigma              -3.297426
# gamma              -2.201346
# jitter             -0.009186
# Name: 107, dtype: object)
# (526, teff                    2300
# logg                     2.5
# Z                        0.0
# center              11617.66
# shift_center    11617.647985
# amp                -2.288572
# sigma              -3.363384
# gamma               -2.33677
# jitter             -0.012015
# Name: 526, dtype: object)
# (156, teff                    2300
# logg                     3.0
# Z                        0.0
# center              11617.66
# shift_center    11617.650375
# amp                -2.345414
# sigma              -3.422233
# gamma              -2.472242
# jitter             -0.009625
# Name: 156, dtype: object)
# (426, teff                    2300
# logg                     3.5
# Z                        0.0
# center              11617.66
# shift_center    11617.651222
# amp                -2.447347
# sigma              -3.400805
# gamma              -2.661644
# jitter             -0.008778
# Name: 426, dtype: object)
# (559, teff                   2300
# logg                    4.0
# Z                       0.0
# center             11617.66
# shift_center    11617.65319
# amp               -2.663025
# sigma              -3.30904
# gamma             -3.016257
# jitter             -0.00681
# Name: 559, dtype: object)
# (219, teff                    2300
# logg                     4.5
# Z                        0.0
# center              11617.66
# shift_center    11617.654111
# amp                -2.827921
# sigma              -3.288052
# gamma              -3.436413
# jitter             -0.005889
# Name: 219, dtype: object)
# (333, teff                    2300
# logg                     5.0
# Z                        0.0
# center              11617.66
# shift_center    11617.654622
# amp                -2.821826
# sigma              -3.312422
# gamma              -3.602385
# jitter             -0.005378
# Name: 333, dtype: object)
# (44, teff                    2300
# logg                     5.5
# Z                        0.0
# center              11617.66
# shift_center    11617.657083
# amp                -2.497701
# sigma              -3.263983
# gamma              -3.198135
# jitter             -0.002917
# Name: 44, dtype: object)
# (272, teff                    2300
# logg                     6.0
# Z                        0.0
# center              11617.66
# shift_center    11617.653661
# amp                -2.413372
# sigma              -3.205805
# gamma              -3.162644
# jitter             -0.006339
# Name: 272, dtype: object)
# (135, teff                    2400
# logg                     2.0
# Z                        0.0
# center              11617.66
# shift_center    11617.648648
# amp                -2.311837
# sigma              -3.334098
# gamma              -2.220648
# jitter             -0.011352
# Name: 135, dtype: object)
# (349, teff                    2400
# logg                     2.5
# Z                        0.0
# center              11617.66
# shift_center    11617.649555
# amp                -2.460509
# sigma               -3.40243
# gamma              -2.378344
# jitter             -0.010445
# Name: 349, dtype: object)
# (70, teff                    2400
# logg                     3.0
# Z                        0.0
# center              11617.66
# shift_center    11617.650841
# amp                -2.561258
# sigma              -3.433428
# gamma              -2.553584
# jitter             -0.009159
# Name: 70, dtype: object)
# (605, teff                    2400
# logg                     3.5
# Z                        0.0
# center              11617.66
# shift_center    11617.652119
# amp                -2.635961
# sigma              -3.387015
# gamma              -2.735229
# jitter             -0.007881
# Name: 605, dtype: object)
# (381, teff                    2400
# logg                     4.0
# Z                        0.0
# center              11617.66
# shift_center    11617.653037
# amp                -2.730701
# sigma              -3.363959
# gamma              -2.964878
# jitter             -0.006963
# Name: 381, dtype: object)
# (484, teff                    2400
# logg                     4.5
# Z                        0.0
# center              11617.66
# shift_center    11617.654435
# amp                -2.766766
# sigma              -3.314444
# gamma              -3.193644
# jitter             -0.005565
# Name: 484, dtype: object)
# (11, teff                    2400
# logg                     5.0
# Z                        0.0
# center              11617.66
# shift_center    11617.653347
# amp                -3.007247
# sigma              -3.342695
# gamma              -3.815499
# jitter             -0.006653
# Name: 11, dtype: object)
# (630, teff                    2400
# logg                     5.5
# Z                        0.0
# center              11617.66
# shift_center    11617.654719
# amp                -2.696047
# sigma              -3.305606
# gamma              -3.443901
# jitter             -0.005281
# Name: 630, dtype: object)
# (543, teff                    2400
# logg                     6.0
# Z                        0.0
# center              11617.66
# shift_center    11617.653247
# amp                -2.484847
# sigma              -3.266588
# gamma              -3.205669
# jitter             -0.006753
# Name: 543, dtype: object)
# (136, teff                    2500
# logg                     2.0
# Z                        0.0
# center              11617.66
# shift_center    11617.651412
# amp                -2.322643
# sigma              -3.230268
# gamma              -2.115825
# jitter             -0.008588
# Name: 136, dtype: object)
# (385, teff                    2500
# logg                     2.5
# Z                        0.0
# center              11617.66
# shift_center    11617.650206
# amp                -2.585047
# sigma              -3.412447
# gamma              -2.373681
# jitter             -0.009794
# Name: 385, dtype: object)
# (241, teff                    2500
# logg                     3.0
# Z                        0.0
# center              11617.66
# shift_center    11617.651933
# amp                -2.736344
# sigma              -3.454893
# gamma              -2.595965
# jitter             -0.008067
# Name: 241, dtype: object)
# (230, teff                    2500
# logg                     3.5
# Z                        0.0
# center              11617.66
# shift_center    11617.652687
# amp                 -2.81476
# sigma              -3.412432
# gamma              -2.783856
# jitter             -0.007313
# Name: 230, dtype: object)
# (297, teff                    2500
# logg                     4.0
# Z                        0.0
# center              11617.66
# shift_center    11617.653372
# amp                -2.831067
# sigma              -3.388276
# gamma              -2.957388
# jitter             -0.006628
# Name: 297, dtype: object)
# (144, teff                    2500
# logg                     4.5
# Z                        0.0
# center              11617.66
# shift_center    11617.655036
# amp                -2.933746
# sigma              -3.302498
# gamma              -3.310825
# jitter             -0.004964
# Name: 144, dtype: object)
# (19, teff                   2500
# logg                    5.0
# Z                       0.0
# center             11617.66
# shift_center    11617.65541
# amp               -2.956379
# sigma             -3.309696
# gamma             -3.573391
# jitter             -0.00459
# Name: 19, dtype: object)
# (331, teff                    2500
# logg                     5.5
# Z                        0.0
# center              11617.66
# shift_center    11617.653813
# amp                -2.902899
# sigma              -3.315441
# gamma              -3.719359
# jitter             -0.006187
# Name: 331, dtype: object)
# (320, teff                    2500
# logg                     6.0
# Z                        0.0
# center              11617.66
# shift_center    11617.653127
# amp                -2.580902
# sigma              -3.271737
# gamma              -3.308123
# jitter             -0.006873
# Name: 320, dtype: object)
# (463, teff                    2600
# logg                     2.0
# Z                        0.0
# center              11617.66
# shift_center    11617.654117
# amp                -2.319579
# sigma              -3.224115
# gamma              -2.035114
# jitter             -0.005883
# Name: 463, dtype: object)
# (216, teff                    2600
# logg                     2.5
# Z                        0.0
# center              11617.66
# shift_center    11617.653626
# amp                -2.652087
# sigma               -3.33454
# gamma              -2.291263
# jitter             -0.006374
# Name: 216, dtype: object)
# (545, teff                    2600
# logg                     3.0
# Z                        0.0
# center              11617.66
# shift_center    11617.652255
# amp                -2.939094
# sigma              -3.443199
# gamma              -2.653531
# jitter             -0.007745
# Name: 545, dtype: object)
# (435, teff                    2600
# logg                     3.5
# Z                        0.0
# center              11617.66
# shift_center    11617.653263
# amp                -3.016723
# sigma              -3.422457
# gamma              -2.847656
# jitter             -0.006737
# Name: 435, dtype: object)
# (33, teff                    2600
# logg                     4.0
# Z                        0.0
# center              11617.66
# shift_center    11617.653217
# amp                -3.007771
# sigma               -3.37959
# gamma              -3.016677
# jitter             -0.006783
# Name: 33, dtype: object)
# (640, teff                   2600
# logg                    4.5
# Z                       0.0
# center             11617.66
# shift_center    11617.65389
# amp               -3.103521
# sigma             -3.299492
# gamma             -3.392617
# jitter             -0.00611
# Name: 640, dtype: object)
# (222, teff                    2600
# logg                     5.0
# Z                        0.0
# center              11617.66
# shift_center    11617.653724
# amp                -3.049131
# sigma              -3.312112
# gamma              -3.571434
# jitter             -0.006276
# Name: 222, dtype: object)
# (184, teff                    2600
# logg                     5.5
# Z                        0.0
# center              11617.66
# shift_center    11617.654462
# amp                -2.911474
# sigma              -3.307065
# gamma              -3.580533
# jitter             -0.005538
# Name: 184, dtype: object)
# (402, teff                    2600
# logg                     6.0
# Z                        0.0
# center              11617.66
# shift_center    11617.656327
# amp                  -2.6853
# sigma              -3.299143
# gamma              -3.389313
# jitter             -0.003673
# Name: 402, dtype: object)
# (562, teff                    2700
# logg                     2.0
# Z                        0.0
# center              11617.66
# shift_center    11617.655371
# amp                -2.497322
# sigma              -3.258941
# gamma              -2.118411
# jitter             -0.004629
# Name: 562, dtype: object)
# (582, teff                    2700
# logg                     2.5
# Z                        0.0
# center              11617.66
# shift_center    11617.654411
# amp                -2.801102
# sigma              -3.337372
# gamma              -2.336789
# jitter             -0.005589
# Name: 582, dtype: object)
# (203, teff                    2700
# logg                     3.0
# Z                        0.0
# center              11617.66
# shift_center    11617.654124
# amp                -3.098831
# sigma               -3.39119
# gamma               -2.66957
# jitter             -0.005876
# Name: 203, dtype: object)
# (376, teff                    2700
# logg                     3.5
# Z                        0.0
# center              11617.66
# shift_center    11617.653439
# amp                -3.220305
# sigma              -3.410539
# gamma              -2.922148
# jitter             -0.006561
# Name: 376, dtype: object)
# (286, teff                   2700
# logg                    4.0
# Z                       0.0
# center             11617.66
# shift_center    11617.65345
# amp               -3.241665
# sigma             -3.373467
# gamma             -3.132943
# jitter             -0.00655
# Name: 286, dtype: object)
# (436, teff                    2700
# logg                     4.5
# Z                        0.0
# center              11617.66
# shift_center    11617.653897
# amp                -3.256059
# sigma              -3.315594
# gamma              -3.433526
# jitter             -0.006103
# Name: 436, dtype: object)
# (544, teff                    2700
# logg                     5.0
# Z                        0.0
# center              11617.66
# shift_center    11617.655528
# amp                -3.215056
# sigma              -3.322688
# gamma                -3.6662
# jitter             -0.004472
# Name: 544, dtype: object)
# (86, teff                    2700
# logg                     5.5
# Z                        0.0
# center              11617.66
# shift_center    11617.653533
# amp                -3.097906
# sigma              -3.333774
# gamma              -3.750431
# jitter             -0.006467
# Name: 86, dtype: object)
# (99, teff                    2700
# logg                     6.0
# Z                        0.0
# center              11617.66
# shift_center    11617.654305
# amp                 -2.79626
# sigma              -3.301952
# gamma              -3.452647
# jitter             -0.005695
# Name: 99, dtype: object)
# (251, teff                    2800
# logg                     2.0
# Z                        0.0
# center              11617.66
# shift_center    11617.656338
# amp                -2.607103
# sigma              -3.292836
# gamma               -2.17944
# jitter             -0.003662
# Name: 251, dtype: object)
# (148, teff                    2800
# logg                     2.5
# Z                        0.0
# center              11617.66
# shift_center    11617.655329
# amp                -2.991682
# sigma              -3.320846
# gamma              -2.423071
# jitter             -0.004671
# Name: 148, dtype: object)
# (423, teff                    2800
# logg                     3.0
# Z                        0.0
# center              11617.66
# shift_center    11617.655691
# amp                -3.261258
# sigma              -3.344078
# gamma              -2.698387
# jitter             -0.004309
# Name: 423, dtype: object)
# (240, teff                    2800
# logg                     3.5
# Z                        0.0
# center              11617.66
# shift_center    11617.653742
# amp                 -3.43553
# sigma              -3.372843
# gamma              -3.011246
# jitter             -0.006258
# Name: 240, dtype: object)
# (502, teff                    2800
# logg                     4.0
# Z                        0.0
# center              11617.66
# shift_center    11617.653939
# amp                 -3.41757
# sigma              -3.375157
# gamma              -3.182706
# jitter             -0.006061
# Name: 502, dtype: object)
# (635, teff                    2800
# logg                     4.5
# Z                        0.0
# center              11617.66
# shift_center    11617.654134
# amp                 -3.40659
# sigma              -3.333204
# gamma              -3.448011
# jitter             -0.005866
# Name: 635, dtype: object)
# (296, teff                    2800
# logg                     5.0
# Z                        0.0
# center              11617.66
# shift_center    11617.654232
# amp                -3.349825
# sigma              -3.336448
# gamma              -3.670789
# jitter             -0.005768
# Name: 296, dtype: object)
# (341, teff                    2800
# logg                     5.5
# Z                        0.0
# center              11617.66
# shift_center    11617.655244
# amp                -3.226382
# sigma              -3.342828
# gamma              -3.780917
# jitter             -0.004756
# Name: 341, dtype: object)
# (530, teff                    2800
# logg                     6.0
# Z                        0.0
# center              11617.66
# shift_center    11617.658393
# amp                -2.963253
# sigma              -3.305994
# gamma              -3.609472
# jitter             -0.001607
# Name: 530, dtype: object)
# (117, teff                    2900
# logg                     2.0
# Z                        0.0
# center              11617.66
# shift_center    11617.654572
# amp                -2.868997
# sigma              -3.261064
# gamma              -2.333332
# jitter             -0.005428
# Name: 117, dtype: object)
# (389, teff                    2900
# logg                     2.5
# Z                        0.0
# center              11617.66
# shift_center    11617.655667
# amp                -3.198422
# sigma              -3.279522
# gamma              -2.530534
# jitter             -0.004333
# Name: 389, dtype: object)
# (615, teff                    2900
# logg                     3.0
# Z                        0.0
# center              11617.66
# shift_center    11617.656105
# amp                -3.518494
# sigma              -3.280318
# gamma              -2.863662
# jitter             -0.003895
# Name: 615, dtype: object)
# (589, teff                    2900
# logg                     3.5
# Z                        0.0
# center              11617.66
# shift_center    11617.653881
# amp                -3.655823
# sigma              -3.322464
# gamma              -3.135118
# jitter             -0.006119
# Name: 589, dtype: object)
# (567, teff                    2900
# logg                     4.0
# Z                        0.0
# center              11617.66
# shift_center    11617.654012
# amp                -3.607677
# sigma              -3.368157
# gamma              -3.256822
# jitter             -0.005988
# Name: 567, dtype: object)
# (648, teff                    2900
# logg                     4.5
# Z                        0.0
# center              11617.66
# shift_center    11617.654244
# amp                -3.503206
# sigma              -3.363062
# gamma              -3.368103
# jitter             -0.005756
# Name: 648, dtype: object)
# (452, teff                   2900
# logg                    5.0
# Z                       0.0
# center             11617.66
# shift_center    11617.65406
# amp                -3.48064
# sigma             -3.347696
# gamma             -3.654697
# jitter             -0.00594
# Name: 452, dtype: object)
# (55, teff                    2900
# logg                     5.5
# Z                        0.0
# center              11617.66
# shift_center    11617.655799
# amp                -3.304123
# sigma              -3.345749
# gamma               -3.68641
# jitter             -0.004201
# Name: 55, dtype: object)
# (591, teff                    2900
# logg                     6.0
# Z                        0.0
# center              11617.66
# shift_center    11617.654779
# amp                -3.138565
# sigma              -3.334138
# gamma              -3.730372
# jitter             -0.005221
# Name: 591, dtype: object)
# (42, teff                   3000
# logg                    2.0
# Z                       0.0
# center             11617.66
# shift_center    11617.65449
# amp               -3.235528
# sigma             -3.204224
# gamma             -2.468371
# jitter             -0.00551
# Name: 42, dtype: object)
# (548, teff                    3000
# logg                     2.5
# Z                        0.0
# center              11617.66
# shift_center    11617.656466
# amp                -3.374992
# sigma              -3.281803
# gamma              -2.636912
# jitter             -0.003534
# Name: 548, dtype: object)
# (443, teff                    3000
# logg                     3.0
# Z                        0.0
# center              11617.66
# shift_center    11617.656021
# amp                 -3.73755
# sigma              -3.230864
# gamma              -3.034452
# jitter             -0.003979
# Name: 443, dtype: object)
# (360, teff                    3000
# logg                     3.5
# Z                        0.0
# center              11617.66
# shift_center    11617.654123
# amp                 -3.83663
# sigma              -3.313999
# gamma              -3.239283
# jitter             -0.005877
# Name: 360, dtype: object)
# (596, teff                    3000
# logg                     4.0
# Z                        0.0
# center              11617.66
# shift_center    11617.653733
# amp                -3.852358
# sigma              -3.333793
# gamma               -3.43561
# jitter             -0.006267
# Name: 596, dtype: object)
# (357, teff                    3000
# logg                     4.5
# Z                        0.0
# center              11617.66
# shift_center    11617.653747
# amp                -3.771468
# sigma                -3.3405
# gamma               -3.57261
# jitter             -0.006253
# Name: 357, dtype: object)
# (471, teff                    3000
# logg                     5.0
# Z                        0.0
# center              11617.66
# shift_center    11617.653699
# amp                -3.654567
# sigma              -3.343929
# gamma              -3.711654
# jitter             -0.006301
# Name: 471, dtype: object)
# (182, teff                    3000
# logg                     5.5
# Z                        0.0
# center              11617.66
# shift_center    11617.654311
# amp                -3.492648
# sigma               -3.34524
# gamma              -3.795057
# jitter             -0.005689
# Name: 182, dtype: object)
# (280, teff                    3000
# logg                     6.0
# Z                        0.0
# center              11617.66
# shift_center    11617.653639
# amp                -3.256575
# sigma              -3.321562
# gamma              -3.755431
# jitter             -0.006361
# Name: 280, dtype: object)
# (308, teff                    3100
# logg                     2.0
# Z                        0.0
# center              11617.66
# shift_center    11617.656862
# amp                -3.680206
# sigma              -2.976243
# gamma              -2.803019
# jitter             -0.003138
# Name: 308, dtype: object)
# (546, teff                    3100
# logg                     2.5
# Z                        0.0
# center              11617.66
# shift_center    11617.656671
# amp                -3.580441
# sigma              -3.187769
# gamma              -2.868851
# jitter             -0.003329
# Name: 546, dtype: object)
# (399, teff                    3100
# logg                     3.0
# Z                        0.0
# center              11617.66
# shift_center    11617.656058
# amp                -3.912726
# sigma              -3.249151
# gamma              -3.217354
# jitter             -0.003942
# Name: 399, dtype: object)
# (145, teff                    3100
# logg                     3.5
# Z                        0.0
# center              11617.66
# shift_center    11617.654222
# amp                -4.017373
# sigma              -3.311905
# gamma              -3.398731
# jitter             -0.005778
# Name: 145, dtype: object)
# (121, teff                    3100
# logg                     4.0
# Z                        0.0
# center              11617.66
# shift_center    11617.654056
# amp                -4.020045
# sigma              -3.339791
# gamma              -3.531256
# jitter             -0.005944
# Name: 121, dtype: object)
# (638, teff                    3100
# logg                     4.5
# Z                        0.0
# center              11617.66
# shift_center    11617.653923
# amp                -3.871735
# sigma              -3.355483
# gamma              -3.520349
# jitter             -0.006077
# Name: 638, dtype: object)
# (400, teff                    3100
# logg                     5.0
# Z                        0.0
# center              11617.66
# shift_center    11617.653804
# amp                 -3.82166
# sigma              -3.356677
# gamma              -3.768803
# jitter             -0.006196
# Name: 400, dtype: object)
# (621, teff                    3100
# logg                     5.5
# Z                        0.0
# center              11617.66
# shift_center    11617.653554
# amp                -3.647719
# sigma              -3.351939
# gamma               -3.83285
# jitter             -0.006446
# Name: 621, dtype: object)
# (511, teff                    3100
# logg                     6.0
# Z                        0.0
# center              11617.66
# shift_center    11617.653917
# amp                -3.328518
# sigma              -3.322491
# gamma              -3.641878
# jitter             -0.006083
# Name: 511, dtype: object)
# (607, teff                    3200
# logg                     2.0
# Z                        0.0
# center              11617.66
# shift_center    11617.655725
# amp                -4.034624
# sigma              -3.337608
# gamma              -3.378729
# jitter             -0.004275
# Name: 607, dtype: object)
# (309, teff                    3200
# logg                     2.5
# Z                        0.0
# center              11617.66
# shift_center    11617.656198
# amp                -3.923192
# sigma              -3.290302
# gamma               -3.34114
# jitter             -0.003802
# Name: 309, dtype: object)
# (560, teff                    3200
# logg                     3.0
# Z                        0.0
# center              11617.66
# shift_center    11617.655957
# amp                -4.028337
# sigma              -3.293156
# gamma              -3.370816
# jitter             -0.004043
# Name: 560, dtype: object)
# (420, teff                    3200
# logg                     3.5
# Z                        0.0
# center              11617.66
# shift_center    11617.654562
# amp                -4.161387
# sigma              -3.345692
# gamma              -3.523266
# jitter             -0.005438
# Name: 420, dtype: object)
# (445, teff                  3200
# logg                   4.0
# Z                      0.0
# center            11617.66
# shift_center    11617.6543
# amp              -4.147907
# sigma             -3.36107
# gamma            -3.581139
# jitter             -0.0057
# Name: 445, dtype: object)
# (151, teff                    3200
# logg                     4.5
# Z                        0.0
# center              11617.66
# shift_center    11617.654104
# amp                -4.045123
# sigma              -3.367624
# gamma              -3.605784
# jitter             -0.005896
# Name: 151, dtype: object)
# (242, teff                    3200
# logg                     5.0
# Z                        0.0
# center              11617.66
# shift_center    11617.654131
# amp                -3.909389
# sigma              -3.365454
# gamma              -3.663265
# jitter             -0.005869
# Name: 242, dtype: object)
# (258, teff                    3200
# logg                     5.5
# Z                        0.0
# center              11617.66
# shift_center    11617.653787
# amp                -3.792015
# sigma              -3.361685
# gamma              -3.820765
# jitter             -0.006213
# Name: 258, dtype: object)
# (407, teff                    3200
# logg                     6.0
# Z                        0.0
# center              11617.66
# shift_center    11617.653671
# amp                -3.565645
# sigma              -3.343486
# gamma               -3.80917
# jitter             -0.006329
# Name: 407, dtype: object)
# (507, teff                    3300
# logg                     2.0
# Z                        0.0
# center              11617.66
# shift_center    11617.656779
# amp                -4.215662
# sigma              -3.335409
# gamma              -3.483099
# jitter             -0.003221
# Name: 507, dtype: object)
# (234, teff                    3300
# logg                     2.5
# Z                        0.0
# center              11617.66
# shift_center    11617.656067
# amp                -4.102045
# sigma              -3.336345
# gamma               -3.48792
# jitter             -0.003933
# Name: 234, dtype: object)
# (295, teff                    3300
# logg                     3.0
# Z                        0.0
# center              11617.66
# shift_center    11617.654703
# amp                -4.128822
# sigma              -3.334646
# gamma              -3.508553
# jitter             -0.005297
# Name: 295, dtype: object)
# (236, teff                    3300
# logg                     3.5
# Z                        0.0
# center              11617.66
# shift_center    11617.654625
# amp                -4.264936
# sigma              -3.357841
# gamma              -3.606401
# jitter             -0.005375
# Name: 236, dtype: object)
# (369, teff                    3300
# logg                     4.0
# Z                        0.0
# center              11617.66
# shift_center    11617.654206
# amp                -4.289462
# sigma              -3.377643
# gamma              -3.681847
# jitter             -0.005794
# Name: 369, dtype: object)
# (80, teff                   3300
# logg                    4.5
# Z                       0.0
# center             11617.66
# shift_center    11617.65423
# amp               -4.190632
# sigma             -3.387666
# gamma             -3.659998
# jitter             -0.00577
# Name: 80, dtype: object)
# (495, teff                    3300
# logg                     5.0
# Z                        0.0
# center              11617.66
# shift_center    11617.658358
# amp                -4.041509
# sigma               -3.38589
# gamma              -3.655806
# jitter             -0.001642
# Name: 495, dtype: object)
# (654, teff                    3300
# logg                     5.5
# Z                        0.0
# center              11617.66
# shift_center    11617.657558
# amp                -3.909121
# sigma              -3.377485
# gamma              -3.764404
# jitter             -0.002442
# Name: 654, dtype: object)
# (285, teff                    3300
# logg                     6.0
# Z                        0.0
# center              11617.66
# shift_center    11617.653721
# amp                -3.725325
# sigma              -3.353523
# gamma              -3.827388
# jitter             -0.006279
# Name: 285, dtype: object)
# (540, teff                    3400
# logg                     2.0
# Z                        0.0
# center              11617.66
# shift_center    11617.656658
# amp                -4.394232
# sigma              -3.337388
# gamma              -3.573032
# jitter             -0.003342
# Name: 540, dtype: object)
# (386, teff                    3400
# logg                     2.5
# Z                        0.0
# center              11617.66
# shift_center    11617.654815
# amp                -4.260082
# sigma              -3.364247
# gamma               -3.57754
# jitter             -0.005185
# Name: 386, dtype: object)
# (491, teff                    3400
# logg                     3.0
# Z                        0.0
# center              11617.66
# shift_center    11617.654828
# amp                -4.246993
# sigma              -3.346718
# gamma              -3.581494
# jitter             -0.005172
# Name: 491, dtype: object)
# (319, teff                   3400
# logg                    3.5
# Z                       0.0
# center             11617.66
# shift_center    11617.65441
# amp               -4.344115
# sigma             -3.378291
# gamma             -3.663145
# jitter             -0.00559
# Name: 319, dtype: object)
# (439, teff                    3400
# logg                     4.0
# Z                        0.0
# center              11617.66
# shift_center    11617.658444
# amp                -4.383705
# sigma              -3.392261
# gamma              -3.696361
# jitter             -0.001556
# Name: 439, dtype: object)
# (51, teff                    3400
# logg                     4.5
# Z                        0.0
# center              11617.66
# shift_center    11617.654008
# amp                -4.326598
# sigma              -3.398416
# gamma              -3.725879
# jitter             -0.005992
# Name: 51, dtype: object)
# (178, teff                    3400
# logg                     5.0
# Z                        0.0
# center              11617.66
# shift_center    11617.656534
# amp                -4.206225
# sigma              -3.396168
# gamma              -3.728525
# jitter             -0.003466
# Name: 178, dtype: object)
# (354, teff                    3400
# logg                     5.5
# Z                        0.0
# center              11617.66
# shift_center    11617.658406
# amp                -3.987235
# sigma              -3.382449
# gamma              -3.657249
# jitter             -0.001594
# Name: 354, dtype: object)
# (199, teff                    3400
# logg                     6.0
# Z                        0.0
# center              11617.66
# shift_center    11617.653982
# amp                -3.836189
# sigma              -3.357654
# gamma               -3.75583
# jitter             -0.006018
# Name: 199, dtype: object)
# (553, teff                   3500
# logg                    2.0
# Z                       0.0
# center             11617.66
# shift_center    11617.65413
# amp                -4.57145
# sigma             -3.344467
# gamma             -3.673822
# jitter             -0.00587
# Name: 553, dtype: object)
# (124, teff                    3500
# logg                     2.5
# Z                        0.0
# center              11617.66
# shift_center    11617.654167
# amp                -4.416664
# sigma              -3.354863
# gamma              -3.670174
# jitter             -0.005833
# Name: 124, dtype: object)
# (132, teff                    3500
# logg                     3.0
# Z                        0.0
# center              11617.66
# shift_center    11617.654346
# amp                -4.336972
# sigma              -3.348666
# gamma              -3.661564
# jitter             -0.005654
# Name: 132, dtype: object)
# (455, teff                    3500
# logg                     3.5
# Z                        0.0
# center              11617.66
# shift_center    11617.656827
# amp                -4.413057
# sigma              -3.388192
# gamma              -3.707754
# jitter             -0.003173
# Name: 455, dtype: object)
# (352, teff                    3500
# logg                     4.0
# Z                        0.0
# center              11617.66
# shift_center    11617.656448
# amp                -4.470828
# sigma              -3.405999
# gamma              -3.746666
# jitter             -0.003552
# Name: 352, dtype: object)
# (571, teff                    3500
# logg                     4.5
# Z                        0.0
# center              11617.66
# shift_center    11617.653789
# amp                -4.443184
# sigma              -3.410605
# gamma              -3.769674
# jitter             -0.006211
# Name: 571, dtype: object)
# (569, teff                   3500
# logg                    5.0
# Z                       0.0
# center             11617.66
# shift_center    11617.65623
# amp                -4.34273
# sigma             -3.403987
# gamma             -3.769969
# jitter             -0.00377
# Name: 569, dtype: object)
# (512, teff                    3500
# logg                     5.5
# Z                        0.0
# center              11617.66
# shift_center    11617.656202
# amp                -4.131221
# sigma              -3.391926
# gamma              -3.679144
# jitter             -0.003798
# Name: 512, dtype: object)
# (31, teff                    3500
# logg                     6.0
# Z                        0.0
# center              11617.66
# shift_center    11617.656565
# amp                -3.956543
# sigma              -3.372891
# gamma              -3.714461
# jitter             -0.003435
# Name: 31, dtype: object)
# (147, teff                    3600
# logg                     2.0
# Z                        0.0
# center              11617.66
# shift_center    11617.653511
# amp                -4.760439
# sigma              -3.373094
# gamma              -3.753557
# jitter             -0.006489
# Name: 147, dtype: object)
# (149, teff                    3600
# logg                     2.5
# Z                        0.0
# center              11617.66
# shift_center    11617.653705
# amp                -4.574602
# sigma              -3.342741
# gamma              -3.721029
# jitter             -0.006295
# Name: 149, dtype: object)
# (317, teff                    3600
# logg                     3.0
# Z                        0.0
# center              11617.66
# shift_center    11617.654002
# amp                -4.402362
# sigma              -3.375292
# gamma              -3.716427
# jitter             -0.005998
# Name: 317, dtype: object)
# (486, teff                    3600
# logg                     3.5
# Z                        0.0
# center              11617.66
# shift_center    11617.654053
# amp                -4.477565
# sigma              -3.371285
# gamma              -3.741757
# jitter             -0.005947
# Name: 486, dtype: object)
# (328, teff                    3600
# logg                     4.0
# Z                        0.0
# center              11617.66
# shift_center    11617.653847
# amp                -4.539658
# sigma              -3.403022
# gamma              -3.777912
# jitter             -0.006153
# Name: 328, dtype: object)
# (112, teff                    3600
# logg                     4.5
# Z                        0.0
# center              11617.66
# shift_center    11617.656306
# amp                 -4.54474
# sigma              -3.418934
# gamma              -3.800763
# jitter             -0.003694
# Name: 112, dtype: object)
# (447, teff                    3600
# logg                     5.0
# Z                        0.0
# center              11617.66
# shift_center    11617.656325
# amp                -4.457027
# sigma               -3.41164
# gamma              -3.789914
# jitter             -0.003675
# Name: 447, dtype: object)
# (111, teff                    3600
# logg                     5.5
# Z                        0.0
# center              11617.66
# shift_center    11617.656301
# amp                -4.285353
# sigma              -3.398258
# gamma              -3.734334
# jitter             -0.003699
# Name: 111, dtype: object)
# (244, teff                    3600
# logg                     6.0
# Z                        0.0
# center              11617.66
# shift_center    11617.656082
# amp                -4.058391
# sigma              -3.384023
# gamma              -3.643733
# jitter             -0.003918
# Name: 244, dtype: object)
# (278, teff                    3700
# logg                     2.0
# Z                        0.0
# center              11617.66
# shift_center    11617.653145
# amp                -4.954423
# sigma              -3.356503
# gamma               -3.78919
# jitter             -0.006855
# Name: 278, dtype: object)
# (85, teff                    3700
# logg                     2.5
# Z                        0.0
# center              11617.66
# shift_center    11617.653443
# amp                -4.750015
# sigma               -3.37513
# gamma              -3.795598
# jitter             -0.006557
# Name: 85, dtype: object)
# (302, teff                    3700
# logg                     3.0
# Z                        0.0
# center              11617.66
# shift_center    11617.653729
# amp                -4.557028
# sigma              -3.371661
# gamma              -3.774697
# jitter             -0.006271
# Name: 302, dtype: object)
# (379, teff                    3700
# logg                     3.5
# Z                        0.0
# center              11617.66
# shift_center    11617.656399
# amp                -4.527064
# sigma              -3.373903
# gamma              -3.764407
# jitter             -0.003601
# Name: 379, dtype: object)
# (71, teff                    3700
# logg                     4.0
# Z                        0.0
# center              11617.66
# shift_center    11617.656322
# amp                -4.598157
# sigma               -3.40347
# gamma              -3.793148
# jitter             -0.003678
# Name: 71, dtype: object)
# (424, teff                    3700
# logg                     4.5
# Z                        0.0
# center              11617.66
# shift_center    11617.656319
# amp                -4.635897
# sigma              -3.425576
# gamma              -3.831177
# jitter             -0.003681
# Name: 424, dtype: object)
# (129, teff                    3700
# logg                     5.0
# Z                        0.0
# center              11617.66
# shift_center    11617.656416
# amp                -4.566172
# sigma              -3.422447
# gamma              -3.811722
# jitter             -0.003584
# Name: 129, dtype: object)
# (153, teff                    3700
# logg                     5.5
# Z                        0.0
# center              11617.66
# shift_center    11617.656249
# amp                 -4.43822
# sigma              -3.407041
# gamma              -3.791119
# jitter             -0.003751
# Name: 153, dtype: object)
# (27, teff                    3700
# logg                     6.0
# Z                        0.0
# center              11617.66
# shift_center    11617.656099
# amp                -4.230578
# sigma              -3.392281
# gamma              -3.708739
# jitter             -0.003901
# Name: 27, dtype: object)
# (56, teff                    3800
# logg                     2.0
# Z                        0.0
# center              11617.66
# shift_center    11617.653157
# amp                 -5.16543
# sigma              -3.331287
# gamma              -3.776654
# jitter             -0.006843
# Name: 56, dtype: object)
# (173, teff                    3800
# logg                     2.5
# Z                        0.0
# center              11617.66
# shift_center    11617.652924
# amp                 -4.94526
# sigma              -3.362005
# gamma              -3.818334
# jitter             -0.007076
# Name: 173, dtype: object)
# (478, teff                    3800
# logg                     3.0
# Z                        0.0
# center              11617.66
# shift_center    11617.653325
# amp                -4.728789
# sigma              -3.386862
# gamma              -3.818115
# jitter             -0.006675
# Name: 478, dtype: object)
# (13, teff                   3800
# logg                    3.5
# Z                       0.0
# center             11617.66
# shift_center    11617.65355
# amp               -4.620898
# sigma             -3.386986
# gamma             -3.813542
# jitter             -0.00645
# Name: 13, dtype: object)
# (586, teff                    3800
# logg                     4.0
# Z                        0.0
# center              11617.66
# shift_center    11617.653661
# amp                -4.658994
# sigma              -3.403675
# gamma              -3.838086
# jitter             -0.006339
# Name: 586, dtype: object)
# (393, teff                    3800
# logg                     4.5
# Z                        0.0
# center              11617.66
# shift_center    11617.656207
# amp                -4.704839
# sigma              -3.426149
# gamma              -3.840272
# jitter             -0.003793
# Name: 393, dtype: object)
# (356, teff                    3800
# logg                     5.0
# Z                        0.0
# center              11617.66
# shift_center    11617.656191
# amp                -4.673561
# sigma              -3.432955
# gamma              -3.835656
# jitter             -0.003809
# Name: 356, dtype: object)
# (364, teff                    3800
# logg                     5.5
# Z                        0.0
# center              11617.66
# shift_center    11617.656297
# amp                -4.568284
# sigma              -3.418319
# gamma              -3.816665
# jitter             -0.003703
# Name: 364, dtype: object)
# (257, teff                    3800
# logg                     6.0
# Z                        0.0
# center              11617.66
# shift_center    11617.656238
# amp                -4.396541
# sigma              -3.399588
# gamma              -3.765979
# jitter             -0.003762
# Name: 257, dtype: object)
# (300, teff                    3900
# logg                     2.0
# Z                        0.0
# center              11617.66
# shift_center    11617.652735
# amp                -5.410279
# sigma              -3.325651
# gamma              -3.732451
# jitter             -0.007265
# Name: 300, dtype: object)
# (338, teff                    3900
# logg                     2.5
# Z                        0.0
# center              11617.66
# shift_center    11617.653674
# amp                -5.171619
# sigma              -3.386411
# gamma              -3.831579
# jitter             -0.006326
# Name: 338, dtype: object)
# (177, teff                    3900
# logg                     3.0
# Z                        0.0
# center              11617.66
# shift_center    11617.652738
# amp                -4.903495
# sigma              -3.435355
# gamma               -3.86139
# jitter             -0.007262
# Name: 177, dtype: object)
# (344, teff                   3900
# logg                    3.5
# Z                       0.0
# center             11617.66
# shift_center    11617.65329
# amp               -4.721455
# sigma             -3.384171
# gamma             -3.841699
# jitter             -0.00671
# Name: 344, dtype: object)
# (150, teff                    3900
# logg                     4.0
# Z                        0.0
# center              11617.66
# shift_center    11617.656129
# amp                -4.735062
# sigma               -3.41619
# gamma              -3.852314
# jitter             -0.003871
# Name: 150, dtype: object)
# (252, teff                    3900
# logg                     4.5
# Z                        0.0
# center              11617.66
# shift_center    11617.656162
# amp                -4.774062
# sigma              -3.432532
# gamma              -3.855417
# jitter             -0.003838
# Name: 252, dtype: object)
# (205, teff                    3900
# logg                     5.0
# Z                        0.0
# center              11617.66
# shift_center    11617.656056
# amp                -4.780909
# sigma              -3.445755
# gamma              -3.866917
# jitter             -0.003944
# Name: 205, dtype: object)
# (92, teff                    3900
# logg                     5.5
# Z                        0.0
# center              11617.66
# shift_center    11617.656177
# amp                -4.704127
# sigma              -3.436135
# gamma              -3.853317
# jitter             -0.003823
# Name: 92, dtype: object)
# (100, teff                   3900
# logg                    6.0
# Z                       0.0
# center             11617.66
# shift_center    11617.65615
# amp               -4.561772
# sigma             -3.413341
# gamma              -3.82284
# jitter             -0.00385
# Name: 100, dtype: object)
# (538, teff                    4000
# logg                     2.0
# Z                        0.0
# center              11617.66
# shift_center    11617.648893
# amp                -5.653205
# sigma              -3.267403
# gamma              -3.590647
# jitter             -0.011107
# Name: 538, dtype: object)
# (580, teff                  4000
# logg                   2.5
# Z                      0.0
# center            11617.66
# shift_center    11617.6537
# amp              -5.450223
# sigma            -3.402303
# gamma            -3.806042
# jitter             -0.0063
# Name: 580, dtype: object)
# (299, teff                    4000
# logg                     3.0
# Z                        0.0
# center              11617.66
# shift_center    11617.652418
# amp                -5.161981
# sigma              -3.391905
# gamma              -3.857416
# jitter             -0.007582
# Name: 299, dtype: object)
# (239, teff                    4000
# logg                     3.5
# Z                        0.0
# center              11617.66
# shift_center    11617.652805
# amp                -4.919698
# sigma              -3.397799
# gamma              -3.868987
# jitter             -0.007195
# Name: 239, dtype: object)
# (197, teff                    4000
# logg                     4.0
# Z                        0.0
# center              11617.66
# shift_center    11617.653299
# amp                -4.827795
# sigma              -3.412651
# gamma              -3.873073
# jitter             -0.006701
# Name: 197, dtype: object)
# (565, teff                    4000
# logg                     4.5
# Z                        0.0
# center              11617.66
# shift_center    11617.656067
# amp                -4.853408
# sigma              -3.437649
# gamma               -3.86895
# jitter             -0.003933
# Name: 565, dtype: object)
# (430, teff                    4000
# logg                     5.0
# Z                        0.0
# center              11617.66
# shift_center    11617.655895
# amp                -4.875414
# sigma              -3.455159
# gamma               -3.87803
# jitter             -0.004105
# Name: 430, dtype: object)
# (574, teff                   4000
# logg                    5.5
# Z                       0.0
# center             11617.66
# shift_center    11617.65588
# amp               -4.835381
# sigma             -3.457544
# gamma             -3.882518
# jitter             -0.00412
# Name: 574, dtype: object)
# (30, teff                    4000
# logg                     6.0
# Z                        0.0
# center              11617.66
# shift_center    11617.656127
# amp                -4.706101
# sigma              -3.428721
# gamma              -3.845108
# jitter             -0.003873
# Name: 30, dtype: object)
# (482, teff                    4100
# logg                     2.0
# Z                        0.0
# center              11617.66
# shift_center    11617.615237
# amp                -5.783533
# sigma              -2.690924
# gamma              -2.955986
# jitter             -0.044763
# Name: 482, dtype: object)
# (273, teff                    4100
# logg                     2.5
# Z                        0.0
# center              11617.66
# shift_center    11617.652206
# amp                -5.750507
# sigma              -3.368423
# gamma              -3.684379
# jitter             -0.007794
# Name: 273, dtype: object)
# (520, teff                    4100
# logg                     3.0
# Z                        0.0
# center              11617.66
# ...
# Z                        0.0
# center              11617.66
# shift_center    11617.648667
# amp                -4.067269
# sigma              -2.216502
# gamma              -2.999189
# jitter             -0.011333
# Name: 54, dtype: object)
# (130, teff                   11000
# logg                     2.0
# Z                        0.0
# center              11617.66
# shift_center    11617.651468
# amp                 -5.82124
# sigma              -2.390917
# gamma              -2.485083
# jitter             -0.008532
# Name: 130, dtype: object)
# (616, teff                   11000
# logg                     2.5
# Z                        0.0
# center              11617.66
# shift_center    11617.641047
# amp                -4.816846
# sigma              -2.216903
# gamma              -1.928328
# jitter             -0.018953
# Name: 616, dtype: object)
# (453, teff                   11000
# logg                     3.0
# Z                        0.0
# center              11617.66
# shift_center    11617.636418
# amp                -3.869557
# sigma              -2.342627
# gamma              -1.066199
# jitter             -0.023582
# Name: 453, dtype: object)
# (52, teff                   11000
# logg                     3.5
# Z                        0.0
# center              11617.66
# shift_center    11617.638541
# amp                 -3.21042
# sigma              -2.422342
# gamma              -0.480609
# jitter             -0.021459
# Name: 52, dtype: object)
# (639, teff                   11000
# logg                     4.0
# Z                        0.0
# center              11617.66
# shift_center    11617.633775
# amp                -3.421873
# sigma              -2.407093
# gamma              -0.812299
# jitter             -0.026225
# Name: 639, dtype: object)
# (212, teff                   11000
# logg                     4.5
# Z                        0.0
# center              11617.66
# shift_center    11617.637368
# amp                -3.681181
# sigma              -2.412395
# gamma               -1.31298
# jitter             -0.022632
# Name: 212, dtype: object)
# (6, teff                   11000
# logg                     5.0
# Z                        0.0
# center              11617.66
# shift_center    11617.647751
# amp                -4.121874
# sigma              -2.231402
# gamma              -2.133529
# jitter             -0.012249
# Name: 6, dtype: object)
# (493, teff                   11000
# logg                     5.5
# Z                        0.0
# center              11617.66
# shift_center    11617.652847
# amp                -4.077082
# sigma              -2.163068
# gamma              -2.431297
# jitter             -0.007153
# Name: 493, dtype: object)
# (118, teff                   11000
# logg                     6.0
# Z                        0.0
# center              11617.66
# shift_center    11617.648135
# amp                -4.248295
# sigma               -2.24195
# gamma              -3.055875
# jitter             -0.011865
# Name: 118, dtype: object)
# (246, teff                   11200
# logg                     2.0
# Z                        0.0
# center              11617.66
# shift_center    11617.650995
# amp                -6.085652
# sigma              -2.387755
# gamma              -2.457337
# jitter             -0.009005
# Name: 246, dtype: object)
# (43, teff                   11200
# logg                     2.5
# Z                        0.0
# center              11617.66
# shift_center    11617.643561
# amp                -5.020829
# sigma              -2.237139
# gamma              -2.085911
# jitter             -0.016439
# Name: 43, dtype: object)
# (490, teff                  11200
# logg                    3.0
# Z                       0.0
# center             11617.66
# shift_center    11617.63714
# amp               -4.186331
# sigma             -2.281023
# gamma             -1.320202
# jitter             -0.02286
# Name: 490, dtype: object)
# (271, teff                   11200
# logg                     3.5
# Z                        0.0
# center              11617.66
# shift_center    11617.639391
# amp                -3.518503
# sigma              -2.391009
# gamma              -0.751166
# jitter             -0.020609
# Name: 271, dtype: object)
# (584, teff                   11200
# logg                     4.0
# Z                        0.0
# center              11617.66
# shift_center    11617.627051
# amp                -3.761724
# sigma              -2.352557
# gamma              -1.079922
# jitter             -0.032949
# Name: 584, dtype: object)
# (617, teff                   11200
# logg                     4.5
# Z                        0.0
# center              11617.66
# shift_center    11617.642724
# amp                -3.798443
# sigma              -2.356857
# gamma              -1.288915
# jitter             -0.017276
# Name: 617, dtype: object)
# (119, teff                   11200
# logg                     5.0
# Z                        0.0
# center              11617.66
# shift_center    11617.646034
# amp                -4.238165
# sigma              -2.208576
# gamma              -2.091929
# jitter             -0.013966
# Name: 119, dtype: object)
# (268, teff                   11200
# logg                     5.5
# Z                        0.0
# center              11617.66
# shift_center    11617.652822
# amp                -4.354163
# sigma              -2.182447
# gamma              -2.654235
# jitter             -0.007178
# Name: 268, dtype: object)
# (627, teff                   11200
# logg                     6.0
# Z                        0.0
# center              11617.66
# shift_center    11617.648425
# amp                -4.205303
# sigma              -2.171145
# gamma              -2.787044
# jitter             -0.011575
# Name: 627, dtype: object)
# (4, teff                   11400
# logg                     2.0
# Z                        0.0
# center              11617.66
# shift_center    11617.650471
# amp                -6.335667
# sigma              -2.381409
# gamma              -2.421592
# jitter             -0.009529
# Name: 4, dtype: object)
# (200, teff                   11400
# logg                     2.5
# Z                        0.0
# center              11617.66
# shift_center    11617.643573
# amp                -5.199815
# sigma              -2.271845
# gamma              -2.214154
# jitter             -0.016427
# Name: 200, dtype: object)
# (353, teff                   11400
# logg                     3.0
# Z                        0.0
# center              11617.66
# shift_center    11617.638117
# amp                -4.468501
# sigma              -2.236087
# gamma              -1.550329
# jitter             -0.021883
# Name: 353, dtype: object)
# (403, teff                   11400
# logg                     3.5
# Z                        0.0
# center              11617.66
# shift_center    11617.643285
# amp                -3.877541
# sigma              -2.333498
# gamma              -1.044717
# jitter             -0.016715
# Name: 403, dtype: object)
# (506, teff                   11400
# logg                     4.0
# Z                        0.0
# center              11617.66
# shift_center    11617.621386
# amp                -4.003407
# sigma              -2.298595
# gamma              -1.247658
# jitter             -0.038614
# Name: 506, dtype: object)
# (577, teff                  11400
# logg                    4.5
# Z                       0.0
# center             11617.66
# shift_center    11617.64074
# amp                -4.09431
# sigma             -2.269706
# gamma             -1.482128
# jitter             -0.01926
# Name: 577, dtype: object)
# (339, teff                   11400
# logg                     5.0
# Z                        0.0
# center              11617.66
# shift_center    11617.644224
# amp                -4.297498
# sigma              -2.193983
# gamma              -1.977896
# jitter             -0.015776
# Name: 339, dtype: object)
# (350, teff                   11400
# logg                     5.5
# Z                        0.0
# center              11617.66
# shift_center    11617.652244
# amp                -4.420796
# sigma              -2.174008
# gamma               -2.55244
# jitter             -0.007756
# Name: 350, dtype: object)
# (415, teff                   11400
# logg                     6.0
# Z                        0.0
# center              11617.66
# shift_center    11617.648084
# amp                -4.353761
# sigma              -2.182505
# gamma              -2.790357
# jitter             -0.011916
# Name: 415, dtype: object)
# (126, teff                  11600
# logg                    2.0
# Z                       0.0
# center             11617.66
# shift_center    11617.64929
# amp               -6.558701
# sigma             -2.369166
# gamma             -2.380488
# jitter             -0.01071
# Name: 126, dtype: object)
# (380, teff                   11600
# logg                     2.5
# Z                        0.0
# center              11617.66
# shift_center    11617.643276
# amp                 -5.37364
# sigma              -2.307171
# gamma              -2.306236
# jitter             -0.016724
# Name: 380, dtype: object)
# (293, teff                   11600
# logg                     3.0
# Z                        0.0
# center              11617.66
# shift_center    11617.639461
# amp                -4.709472
# sigma              -2.216534
# gamma              -1.757266
# jitter             -0.020539
# Name: 293, dtype: object)
# (76, teff                   11600
# logg                     3.5
# Z                        0.0
# center              11617.66
# shift_center    11617.642893
# amp                -4.177662
# sigma              -2.278035
# gamma              -1.283357
# jitter             -0.017107
# Name: 76, dtype: object)
# (458, teff                   11600
# logg                     4.0
# Z                        0.0
# center              11617.66
# shift_center    11617.622344
# amp                -4.308981
# sigma              -2.236458
# gamma              -1.481475
# jitter             -0.037656
# Name: 458, dtype: object)
# (321, teff                   11600
# logg                     4.5
# Z                        0.0
# center              11617.66
# shift_center    11617.638514
# amp                 -3.95229
# sigma              -2.297022
# gamma              -1.230339
# jitter             -0.021486
# Name: 321, dtype: object)
# (235, teff                   11600
# logg                     5.0
# Z                        0.0
# center              11617.66
# shift_center    11617.641777
# amp                -5.332935
# sigma              -2.412742
# gamma               -2.94451
# jitter             -0.018223
# Name: 235, dtype: object)
# (305, teff                   11600
# logg                     5.5
# Z                        0.0
# center              11617.66
# shift_center    11617.652238
# amp                -4.624279
# sigma              -2.180223
# gamma              -2.581255
# jitter             -0.007762
# Name: 305, dtype: object)
# (516, teff                   11600
# logg                     6.0
# Z                        0.0
# center              11617.66
# shift_center    11617.647625
# amp                -4.560506
# sigma              -2.219636
# gamma              -2.861904
# jitter             -0.012375
# Name: 516, dtype: object)
# (259, teff                   11800
# logg                     2.0
# Z                        0.0
# center              11617.66
# shift_center    11617.648735
# amp                -6.788606
# sigma              -2.354136
# gamma              -2.338449
# jitter             -0.011265
# Name: 259, dtype: object)
# (612, teff                   11800
# logg                     2.5
# Z                        0.0
# center              11617.66
# shift_center    11617.643055
# amp                -5.557935
# sigma              -2.332071
# gamma              -2.357807
# jitter             -0.016945
# Name: 612, dtype: object)
# (472, teff                   11800
# logg                     3.0
# Z                        0.0
# center              11617.66
# shift_center    11617.643961
# amp                -4.903131
# sigma              -2.222785
# gamma              -1.930173
# jitter             -0.016039
# Name: 472, dtype: object)
# (179, teff                  11800
# logg                    3.5
# Z                       0.0
# center             11617.66
# shift_center    11617.64382
# amp               -4.886926
# sigma             -2.209411
# gamma             -1.964376
# jitter             -0.01618
# Name: 179, dtype: object)
# (367, teff                   11800
# logg                     4.0
# Z                        0.0
# center              11617.66
# shift_center    11617.640728
# amp                -4.570754
# sigma              -2.202411
# gamma              -1.694422
# jitter             -0.019272
# Name: 367, dtype: object)
# (115, teff                   11800
# logg                     4.5
# Z                        0.0
# center              11617.66
# shift_center    11617.636559
# amp                -4.118111
# sigma              -2.260987
# gamma              -1.326223
# jitter             -0.023441
# Name: 115, dtype: object)
# (329, teff                   11800
# logg                     5.0
# Z                        0.0
# center              11617.66
# shift_center    11617.639675
# amp                -5.546072
# sigma              -2.452039
# gamma              -2.904418
# jitter             -0.020325
# Name: 329, dtype: object)
# (405, teff                   11800
# logg                     5.5
# Z                        0.0
# center              11617.66
# shift_center    11617.652465
# amp                -4.401281
# sigma              -2.144552
# gamma              -2.074256
# jitter             -0.007535
# Name: 405, dtype: object)
# (517, teff                  11800
# logg                    6.0
# Z                       0.0
# center             11617.66
# shift_center    11617.64887
# amp               -4.918189
# sigma             -2.327457
# gamma             -3.050687
# jitter             -0.01113
# Name: 517, dtype: object)
# (310, teff                   12000
# logg                     2.0
# Z                        0.0
# center              11617.66
# shift_center    11617.647665
# amp                -6.927459
# sigma              -2.337377
# gamma              -2.299145
# jitter             -0.012335
# Name: 310, dtype: object)
# (243, teff                   12000
# logg                     2.5
# Z                        0.0
# center              11617.66
# shift_center    11617.642433
# amp                -5.754678
# sigma              -2.344145
# gamma              -2.374711
# jitter             -0.017567
# Name: 243, dtype: object)
# (262, teff                   12000
# logg                     3.0
# Z                        0.0
# center              11617.66
# shift_center    11617.644673
# amp                -5.076929
# sigma              -2.246177
# gamma               -2.07848
# jitter             -0.015327
# Name: 262, dtype: object)
# (263, teff                   12000
# logg                     3.5
# Z                        0.0
# center              11617.66
# shift_center    11617.645152
# amp                 -5.05383
# sigma               -2.23254
# gamma              -2.094359
# jitter             -0.014848
# Name: 263, dtype: object)
# (229, teff                   12000
# logg                     4.0
# Z                        0.0
# center              11617.66
# shift_center    11617.643675
# amp                -4.807964
# sigma               -2.19899
# gamma              -1.891461
# jitter             -0.016325
# Name: 229, dtype: object)
# (462, teff                  12000
# logg                    4.5
# Z                       0.0
# center             11617.66
# shift_center    11617.63433
# amp                -3.79878
# sigma             -2.327936
# gamma             -0.967507
# jitter             -0.02567
# Name: 462, dtype: object)
# (225, teff                   12000
# logg                     5.0
# Z                        0.0
# center              11617.66
# shift_center    11617.638177
# amp                -5.818669
# sigma              -2.497412
# gamma              -2.868438
# jitter             -0.021823
# Name: 225, dtype: object)
# (623, teff                  12000
# logg                    5.5
# Z                       0.0
# center             11617.66
# shift_center    11617.65253
# amp               -4.502795
# sigma             -2.129781
# gamma             -2.043803
# jitter             -0.00747
# Name: 623, dtype: object)
# (619, teff                   12000
# logg                     6.0
# Z                        0.0
# center              11617.66
# shift_center    11617.646862
# amp                -5.104416
# sigma              -2.361187
# gamma              -3.024232
# jitter             -0.013138
# Name: 619, dtype: object)
